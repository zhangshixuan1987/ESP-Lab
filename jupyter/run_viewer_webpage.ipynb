# %% [markdown]
# # ESP-Lab workflow figure gallery
#
# Discover all diagnostic figures generated across the active analysis suite (`jupyter/1a_*.ipynb` through `jupyter/6b_*.ipynb`) and build a searchable, responsive webpage. Includes lead-time ACC maps, lead-time RMSE maps, regional SST indices, modes of variability, ELI diagnostics, initial shock analyses, and teleconnections.

# %%
# ============================================================
# Configuration
# ============================================================
from pathlib import Path

DIAG_DIR = Path("/global/cfs/cdirs/e3sm/www/zhan391/esp-lab_diag")
FIGURE_PATTERN = "fig_*"
INCLUDE_SUBDIRS = True
PORTAL_URL = "https://portal.nersc.gov/cfs/e3sm/zhan391/esp-lab_diag/index.html"

# %%
# Imports
import sys

import pandas as pd
from IPython.display import HTML, display

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "esp_lab").is_dir():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from esp_lab.diagnostics.web import (
    discover_workflow_figures,
    generate_diagnostics_webpage,
)

# %% [markdown]
# ## 1. Discover workflow figures
#
# Scan the directory rather than trusting old manifest entries. The synchronized catalog below is exactly what the webpage will show.

# %%
manifest = discover_workflow_figures(
    DIAG_DIR,
    pattern=FIGURE_PATTERN,
    write_manifest=True,
    include_subdirs=INCLUDE_SUBDIRS,
)
catalog = pd.DataFrame(manifest["figures"])[
    ["file", "group", "mode", "metric", "title", "caption"]
]
print(f"Found {len(catalog)} workflow figures in {DIAG_DIR}")
display(catalog.groupby("group").size().rename("figures").to_frame())
display(catalog)
# Out:
# Found 546 workflow figures in /global/cfs/cdirs/e3sm/www/zhan391/esp-lab_diag
#                  figures
# group
# ELI                    6
# INITIAL_SHOCK         26
# LEAD_ACC              28
# LEAD_RMSE             25
# MOV                   72
# SST_INDEX             26
# TELECONNECTIONS      363
#                                                   file            group mode  \
# 0                                 fig_1a_prect_acc.png         LEAD_ACC
# 1                         fig_1a_prect_acc_compare.png         LEAD_ACC
# 2                      fig_1a_prect_acc_difference.png         LEAD_ACC
# 3                    fig_1a_prect_acc_distribution.png         LEAD_ACC
# 4                                   fig_1a_psl_acc.png         LEAD_ACC
# ..                                                 ...              ...  ...
# 541  teleconnections/teleconnection_TSA_TS_summary.png  TELECONNECTIONS   TS
# 542  teleconnections/teleconnection_TSA_TS_taylor_d...  TELECONNECTIONS   TS
# 543  teleconnections/teleconnection_TSA_TWS_correla...  TELECONNECTIONS   TS
# 544  teleconnections/teleconnection_TSA_TWS_summary...  TELECONNECTIONS   TS
# 545  teleconnections/teleconnection_TSA_TWS_taylor_...  TELECONNECTIONS   TS
#
#                                metric  \
# 0                        leadtime_acc
# 1                leadtime_acc_compare
# 2                   leadtime_acc_diff
# 3    leadtime_acc_smyle_record_length
# 4                        leadtime_acc
# ..                                ...
# 541                           summary
# 542                    taylor_diagram
# 543  correlation_reference_comparison
# 544                           summary
# 545                    taylor_diagram
#
#                                                  title  \
# 0                            Leadtime ACC Skill: PRECT
# 1    Precipitation ACC: CESM-SMYLE and E3SM, linear...
# 2                 Leadtime ACC Skill Difference: PRECT
# 3           CESM-SMYLE Record Length Comparison: PRECT
# 4                              Leadtime ACC Skill: PSL
# ..                                                 ...
# 541                      Teleconnection Tsa TS Summary
# 542               Teleconnection Tsa TS Taylor Diagram
# 543  Teleconnection Tsa TWS Correlation Reference C...
# 544                     Teleconnection Tsa TWS Summary
# 545              Teleconnection Tsa TWS Taylor Diagram
#
#                                                caption
# 0                              ACC skill vs lead month
# 1    ACC comparison for CESM-SMYLE and selected E3S...
# 2    ACC skill difference for selected E3SM hindcas...
# 3    CESM-SMYLE available record (1980–2018, 39yr, ...
# 4                              ACC skill vs lead month
# ..                                                 ...
# 541              Workflow-generated diagnostic figure.
# 542              Workflow-generated diagnostic figure.
# 543              Workflow-generated diagnostic figure.
# 544              Workflow-generated diagnostic figure.
# 545              Workflow-generated diagnostic figure.
#
# [546 rows x 6 columns]

# %% [markdown]
# ## 2. Build the webpage

# %%
output_html = generate_diagnostics_webpage(
    DIAG_DIR,
    discover_figures=True,
    figure_pattern=FIGURE_PATTERN,
    include_subdirs=INCLUDE_SUBDIRS,
)
print(f"Webpage created with {len(catalog)} figures: {output_html}")
display(HTML(f'<a href="{PORTAL_URL}" target="_blank">Open the ESP-Lab figure gallery</a>'))
# Out:
# Webpage created with 546 figures: /global/cfs/cdirs/e3sm/www/zhan391/esp-lab_diag/index.html
# <a href="https://portal.nersc.gov/cfs/e3sm/zhan391/esp-lab_diag/index.html" target="_blank">Open the ESP-Lab figure gallery</a>

# %% [markdown]
# The resulting `index.html` provides group and metric filters, text search, responsive figure cards, full-resolution viewing, and figure comparison. Generation also makes the cataloged figures publicly readable and the gallery directory publicly traversable so the portal can serve every image. Re-run the two sections whenever workflow figures are added, replaced, or removed.

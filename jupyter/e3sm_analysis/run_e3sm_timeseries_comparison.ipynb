# %% [markdown]
# # E3SM Diagnostics: Monthly Time Series Comparison
#
# This notebook generates area-weighted global (or land-masked) monthly time series comparisons for the 4 E3SM simulations (`Reanalysis`, `JRA55_FOSIRL`, `4DEnVar_branch`, `4DEnVar_hybrid`).
#
# It loads the monthly NetCDF files directly from post-processed history directories, handles both single-member and multi-member directory configurations, and plots them with sleek, premium diagnostics styling.

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
import importlib
import os
import sys
from pathlib import Path
from IPython.display import Image, display

# Set project root path
project_root = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "workflows").is_dir())
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

importlib.invalidate_caches()
import workflows.e3sm_analysis.timeseries_comparison as timeseries_workflow
timeseries_workflow = importlib.reload(timeseries_workflow)

load_simulation_timeseries = timeseries_workflow.load_simulation_timeseries
load_observation_timeseries = timeseries_workflow.load_observation_timeseries
plot_timeseries_comparison = timeseries_workflow.plot_timeseries_comparison
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Configuration and Execution Blocks
# Run the monthly, full 6-hourly, and first-month 6-hourly comparison blocks independently as needed.

# %%
# Reload workflow code so this cell can be run by itself after edits.
import importlib
import os
import sys
from pathlib import Path
from IPython.display import Image, display

project_root = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "workflows").is_dir())
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

importlib.invalidate_caches()
import workflows.e3sm_analysis.timeseries_comparison as timeseries_workflow
timeseries_workflow = importlib.reload(timeseries_workflow)
load_simulation_timeseries = timeseries_workflow.load_simulation_timeseries
load_observation_timeseries = timeseries_workflow.load_observation_timeseries
plot_timeseries_comparison = timeseries_workflow.plot_timeseries_comparison

base_dir = "/pscratch/sd/z/zhan391/e3sm_project/E3SMv3_S2D"
output_dir = "/global/cfs/cdirs/e3sm/www/zhan391/E3SMv3_S2D"

simulations = {
    'Reanalysis': {'run_name': 'WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_BruteForce_1980050100', 'ens': 10},
    'JRA55_FOSIRL': {'run_name': 'WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_JRA55_FOSIRL_1980050100', 'ens': 10},
    '4DEnVar_hybrid': {'run_name': 'test_WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_4DEnVar_hybrid', 'ens': 1},
    '4DEnVar_branch': {'run_name': 'test_WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_4DEnVar_branch', 'ens': 1},
}

init_tag = "1980050100"
fontz = 14
figsize = [10, 6]

# ==========================================================
# GENERATE & DISPLAY MONTHLY TIME SERIES COMPARISONS
# ==========================================================
variables = ['TREFHT', 'PRECT', 'PSL', 'SWCF', 'LWCF', 'FLUT']
nlead = 24

for variable in variables:
    print(f"\n--- Processing variable: {variable} ---")
    data = load_simulation_timeseries(base_dir, simulations, variable, init_tag=init_tag, nlead=nlead, frequency="monthly")
    for sim_name, sim_data in data.items():
        print(f"{sim_name}: source grids = {sim_data.get('source_grids', [])}")
    obs_data = None
    #if data:
    #    reference_time = next(iter(data.values())).get("time")
    #    obs_data = load_observation_timeseries(variable, reference_time=reference_time, frequency="monthly")
    plot_timeseries_comparison(data, variable, output_dir, figsize=figsize, fontz=fontz, frequency="monthly", obs_data=obs_data)

    img_path = os.path.join(output_dir, f"e3sm_timeseries_{variable}.png")
    if os.path.exists(img_path):
        display(Image(filename=img_path, width=850))
    else:
        print(f"Warning: Figure not found at {img_path}\n")
# Out:
# --- Processing variable: TREFHT ---
# Reanalysis: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# JRA55_FOSIRL: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# 4DEnVar_hybrid: source grids = ['180x360_aave']
# 4DEnVar_branch: source grids = ['180x360_aave']
# Success! Saved time series comparison to: /global/cfs/cdirs/e3sm/www/zhan391/E3SMv3_S2D/e3sm_timeseries_TREFHT.png
# --- Processing variable: PRECT ---
# Reanalysis: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# ...

# %%
# Reload workflow code so this cell can be run by itself after edits.
import importlib
import os
import sys
from pathlib import Path
from IPython.display import Image, display

project_root = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "workflows").is_dir())
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

importlib.invalidate_caches()
import workflows.e3sm_analysis.timeseries_comparison as timeseries_workflow
timeseries_workflow = importlib.reload(timeseries_workflow)
load_simulation_timeseries = timeseries_workflow.load_simulation_timeseries
load_observation_timeseries = timeseries_workflow.load_observation_timeseries
plot_timeseries_comparison = timeseries_workflow.plot_timeseries_comparison

base_dir = "/pscratch/sd/z/zhan391/e3sm_project/E3SMv3_S2D"
output_dir = "/global/cfs/cdirs/e3sm/www/zhan391/E3SMv3_S2D"

simulations = {
    'Reanalysis': {'run_name': 'WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_BruteForce_1980050100', 'ens': 10},
    'JRA55_FOSIRL': {'run_name': 'WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_JRA55_FOSIRL_1980050100', 'ens': 10},
    '4DEnVar_hybrid': {'run_name': 'test_WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_4DEnVar_hybrid', 'ens': 1},
    '4DEnVar_branch': {'run_name': 'test_WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_4DEnVar_branch', 'ens': 1},
}

init_tag = "1980050100"
fontz = 14
figsize = [10, 6]

# ==========================================================
# GENERATE & DISPLAY 6-HOURLY TIME SERIES COMPARISONS
# ==========================================================
variables_6hourly = ['PRECT', 'TREFHT', 'FLUT']
nlead_6hourly = 1460

for variable in variables_6hourly:
    print(f"\n--- Processing 6-hourly variable: {variable} ---")
    data = load_simulation_timeseries(base_dir, simulations, variable, init_tag=init_tag, nlead=nlead_6hourly, frequency="6hourly")
    for sim_name, sim_data in data.items():
        print(f"{sim_name}: source grids = {sim_data.get('source_grids', [])}")
    obs_data = None
    if data:
        reference_time = next(iter(data.values())).get("time")
        obs_data = load_observation_timeseries(variable, reference_time=reference_time, frequency="6hourly")
    plot_timeseries_comparison(data, variable, output_dir, figsize=figsize, fontz=fontz, frequency="6hourly", obs_data=obs_data)

    img_path = os.path.join(output_dir, f"e3sm_timeseries_6hourly_{variable}.png")
    if os.path.exists(img_path):
        display(Image(filename=img_path, width=850))
    else:
        print(f"Warning: Figure not found at {img_path}\n")
# Out:
# --- Processing 6-hourly variable: PRECT ---
# ...
# Reanalysis: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# JRA55_FOSIRL: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# 4DEnVar_hybrid: source grids = ['180x360_aave']
# 4DEnVar_branch: source grids = ['180x360_aave']
# Success! Saved time series comparison to: /global/cfs/cdirs/e3sm/www/zhan391/E3SMv3_S2D/e3sm_timeseries_6hourly_PRECT.png
# --- Processing 6-hourly variable: TREFHT ---
# ...
# Reanalysis: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# ...

# %%
# Reload workflow code so this cell can be run by itself after edits.
import importlib
import os
import sys
from pathlib import Path
from IPython.display import Image, display

project_root = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "workflows").is_dir())
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

importlib.invalidate_caches()
import workflows.e3sm_analysis.timeseries_comparison as timeseries_workflow
timeseries_workflow = importlib.reload(timeseries_workflow)
load_simulation_timeseries = timeseries_workflow.load_simulation_timeseries
load_observation_timeseries = timeseries_workflow.load_observation_timeseries
plot_timeseries_comparison = timeseries_workflow.plot_timeseries_comparison

base_dir = "/pscratch/sd/z/zhan391/e3sm_project/E3SMv3_S2D"
output_dir = "/global/cfs/cdirs/e3sm/www/zhan391/E3SMv3_S2D"

simulations = {
    'Reanalysis': {'run_name': 'WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_BruteForce_1980050100', 'ens': 10},
    'JRA55_FOSIRL': {'run_name': 'WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_JRA55_FOSIRL_1980050100', 'ens': 10},
    '4DEnVar_hybrid': {'run_name': 'test_WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_4DEnVar_hybrid', 'ens': 1},
    '4DEnVar_branch': {'run_name': 'test_WCYCL20TR_ne30pg2_r05_IcoswISC30E3r5_4DEnVar_branch', 'ens': 1},
}

init_tag = "1980050100"
fontz = 14
figsize = [10, 6]

# ==========================================================
# GENERATE & DISPLAY FIRST-MONTH 6-HOURLY TIME SERIES COMPARISONS
# ==========================================================
variables_6hourly = ['PRECT', 'TREFHT', 'FLUT']
nlead_6hourly_first_month = 124

for variable in variables_6hourly:
    print(f"\n--- Processing first-month 6-hourly variable: {variable} ---")
    data = load_simulation_timeseries(base_dir, simulations, variable, init_tag=init_tag, nlead=nlead_6hourly_first_month, frequency="6hourly")
    for sim_name, sim_data in data.items():
        print(f"{sim_name}: source grids = {sim_data.get('source_grids', [])}")
    obs_data = None
    if data:
        reference_time = next(iter(data.values())).get("time")
        obs_data = load_observation_timeseries(variable, reference_time=reference_time, frequency="6hourly")
    plot_timeseries_comparison(data, variable, output_dir, figsize=figsize, fontz=fontz, frequency="6hourly", output_tag="6hourly_first_month", obs_data=obs_data)

    img_path = os.path.join(output_dir, f"e3sm_timeseries_6hourly_first_month_{variable}.png")
    if os.path.exists(img_path):
        display(Image(filename=img_path, width=850))
    else:
        print(f"Warning: Figure not found at {img_path}\n")
# Out:
# --- Processing first-month 6-hourly variable: PRECT ---
# Reanalysis: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# JRA55_FOSIRL: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# 4DEnVar_hybrid: source grids = ['180x360_aave']
# 4DEnVar_branch: source grids = ['180x360_aave']
# Success! Saved time series comparison to: /global/cfs/cdirs/e3sm/www/zhan391/E3SMv3_S2D/e3sm_timeseries_6hourly_first_month_PRECT.png
# --- Processing first-month 6-hourly variable: TREFHT ---
# Reanalysis: source grids = ['180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave', '180x360_aave']
# ...

# %% [markdown]
# # ESP-Lab workflow figure gallery
#
# Discover all diagnostic figures generated across the active analysis suite (`jupyter/1a_*.ipynb` through `jupyter/7b_*.ipynb`) and build a searchable, responsive webpage. Includes lead-time ACC maps, lead-time RMSE maps, regional ACC/nRMSE curves from `2a_regional_acc_skill_ts.ipynb`, regional SST indices, modes of variability, ELI diagnostics, initial shock analyses, teleconnections, and tropical cyclones.

# %%
# Imports
import sys
from pathlib import Path

import pandas as pd
from IPython.display import HTML, display

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "esp_lab").is_dir():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from esp_lab import env_paths
from esp_lab.diagnostics.web import (
    discover_workflow_figures,
    generate_diagnostics_webpage,
)

# %%
# ============================================================
# Configuration
# ============================================================
DIAG_DIR = env_paths.figure_root()
FIGURE_PATTERN = "fig_*"
INCLUDE_SUBDIRS = True
PORTAL_URL = "https://portal.nersc.gov/cfs/e3sm/zhan391/e3sm-s2d_diag/index.html"

# %% [markdown]
# ## 1. Discover workflow figures
#
# Scan the directory rather than trusting old manifest entries. The synchronized catalog below is exactly what the webpage will show.

# %%
manifest = discover_workflow_figures(
    DIAG_DIR,
    pattern=FIGURE_PATTERN,
    write_manifest=True,
    include_subdirs=INCLUDE_SUBDIRS,
)
catalog = pd.DataFrame(manifest["figures"])[
    ["file", "group", "mode", "metric", "title", "caption"]
]
print(f"Found {len(catalog)} workflow figures in {DIAG_DIR}")
display(catalog.groupby("group").size().rename("figures").to_frame())
display(catalog)
# Out:
# Found 944 workflow figures in /global/cfs/cdirs/e3sm/www/zhan391/e3sm-s2d_diag
#                  figures
# group
# ELI                    6
# INITIAL_SHOCK         28
# LEAD_ACC              35
# LEAD_RMSE             64
# MOV                   72
# REGIONAL_SKILL        84
# SST_INDEX             26
# TC                     5
# TELECONNECTIONS      624
#                                                   file            group mode  \
# 0                            fig_atm_acc_prect_acc.png         LEAD_ACC
# 1            fig_atm_acc_prect_acc_case_difference.png         LEAD_ACC
# 2                    fig_atm_acc_prect_acc_compare.png         LEAD_ACC
# 3                 fig_atm_acc_prect_acc_difference.png         LEAD_ACC
# 4               fig_atm_acc_prect_acc_distribution.png         LEAD_ACC
# ..                                                 ...              ...  ...
# 939              fig_teleconnection_TSA_TS_summary.png  TELECONNECTIONS   TS
# 940       fig_teleconnection_TSA_TS_taylor_diagram.png  TELECONNECTIONS   TS
# 941  fig_teleconnection_TSA_TWS_correlation_referen...  TELECONNECTIONS   TS
# 942             fig_teleconnection_TSA_TWS_summary.png  TELECONNECTIONS   TS
# 943      fig_teleconnection_TSA_TWS_taylor_diagram.png  TELECONNECTIONS   TS
#
#                                metric  \
# 0                        leadtime_acc
# 1             leadtime_acc_difference
# 2                leadtime_acc_compare
# 3                   leadtime_acc_diff
# 4    leadtime_acc_smyle_record_length
# ..                                ...
# 939                           summary
# 940                    taylor_diagram
# 941  correlation_reference_comparison
# 942                           summary
# 943                    taylor_diagram
#
#                                                  title  \
# 0                            Leadtime ACC Skill: PRECT
# 1    Precipitation ACC differences: experiments min...
# 2    Precipitation ACC: CESM-SMYLE and E3SM, linear...
# 3                 Leadtime ACC Skill Difference: PRECT
# 4           CESM-SMYLE Record Length Comparison: PRECT
# ..                                                 ...
# 939                      Teleconnection Tsa TS Summary
# 940               Teleconnection Tsa TS Taylor Diagram
# 941  Teleconnection Tsa TWS Correlation Reference C...
# 942                     Teleconnection Tsa TWS Summary
# 943              Teleconnection Tsa TWS Taylor Diagram
#
#                                                caption
# 0    ACC skill vs lead month; dots mark ACC signifi...
# 1    ACC differences (experiment minus E3SMv3-Reana...
# 2    ACC comparison for CESM-SMYLE and selected E3S...
# 3    ACC skill difference for selected E3SM hindcas...
# 4    CESM-SMYLE available record (1980–2018, 39yr, ...
# ..                                                 ...
# 939              Workflow-generated diagnostic figure.
# 940              Workflow-generated diagnostic figure.
# 941              Workflow-generated diagnostic figure.
# 942              Workflow-generated diagnostic figure.
# 943              Workflow-generated diagnostic figure.
#
# [944 rows x 6 columns]

# %% [markdown]
# ## 2. Build the webpage

# %%
output_html = generate_diagnostics_webpage(
    DIAG_DIR,
    discover_figures=True,
    figure_pattern=FIGURE_PATTERN,
    include_subdirs=INCLUDE_SUBDIRS,
)
print(f"Webpage created with {len(catalog)} figures: {output_html}")
display(HTML(f'<a href="{PORTAL_URL}" target="_blank">Open the ESP-Lab figure gallery</a>'))
# Out:
# Webpage created with 944 figures: /global/cfs/cdirs/e3sm/www/zhan391/e3sm-s2d_diag/index.html
# <a href="https://portal.nersc.gov/cfs/e3sm/zhan391/e3sm-s2d_diag/index.html" target="_blank">Open the ESP-Lab figure gallery</a>

# %% [markdown]
# The resulting `index.html` provides group and metric filters, text search, responsive figure cards, full-resolution viewing, and figure comparison. Generation also makes the cataloged figures publicly readable and the gallery directory publicly traversable so the portal can serve every image. Re-run the two sections whenever workflow figures are added, replaced, or removed.

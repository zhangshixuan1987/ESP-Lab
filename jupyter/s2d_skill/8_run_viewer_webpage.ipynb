# %% [markdown]
# # ESP-Lab workflow figure gallery
#
# Discover all diagnostic figures generated across the active analysis suite (`jupyter/s2d_skill/1a_*.ipynb` through `jupyter/s2d_skill/7b_*.ipynb`) and build a searchable, responsive webpage. Includes lead-time ACC maps, lead-time RMSE maps, regional SST indices, modes of variability, ELI diagnostics, initial shock analyses, teleconnections, and tropical cyclones.

# %%
# ============================================================
# Configuration
# ============================================================
from pathlib import Path

DIAG_DIR = Path("/global/cfs/cdirs/e3sm/www/zhan391/esp-lab_diag")
FIGURE_PATTERN = "fig_*"
INCLUDE_SUBDIRS = True
PORTAL_URL = "https://portal.nersc.gov/cfs/e3sm/zhan391/esp-lab_diag/index.html"

# %%
# Imports
import sys

import pandas as pd
from IPython.display import HTML, display

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "esp_lab").is_dir():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from esp_lab.diagnostics.web import (
    discover_workflow_figures,
    generate_diagnostics_webpage,
)

# %% [markdown]
# ## 1. Discover workflow figures
#
# Scan the directory rather than trusting old manifest entries. The synchronized catalog below is exactly what the webpage will show.

# %%
manifest = discover_workflow_figures(
    DIAG_DIR,
    pattern=FIGURE_PATTERN,
    write_manifest=True,
    include_subdirs=INCLUDE_SUBDIRS,
)
catalog = pd.DataFrame(manifest["figures"])[
    ["file", "group", "mode", "metric", "title", "caption"]
]
print(f"Found {len(catalog)} workflow figures in {DIAG_DIR}")
display(catalog.groupby("group").size().rename("figures").to_frame())
display(catalog)
# Out:
# Found 551 workflow figures in /global/cfs/cdirs/e3sm/www/zhan391/esp-lab_diag
#                  figures
# group
# ELI                    6
# INITIAL_SHOCK         26
# LEAD_ACC              26
# LEAD_RMSE             27
# MOV                   72
# SST_INDEX             26
# TC                     5
# TELECONNECTIONS      363
#                                                   file            group  \
# 0                            fig_atm_acc_prect_acc.png         LEAD_ACC
# 1                    fig_atm_acc_prect_acc_compare.png         LEAD_ACC
# 2                 fig_atm_acc_prect_acc_difference.png         LEAD_ACC
# 3               fig_atm_acc_prect_acc_distribution.png         LEAD_ACC
# 4                              fig_atm_acc_psl_acc.png         LEAD_ACC
# ..                                                 ...              ...
# 546              fig_teleconnection_TSA_TS_summary.png  TELECONNECTIONS
# 547       fig_teleconnection_TSA_TS_taylor_diagram.png  TELECONNECTIONS
# 548  fig_teleconnection_TSA_TWS_correlation_referen...  TELECONNECTIONS
# 549             fig_teleconnection_TSA_TWS_summary.png  TELECONNECTIONS
# 550      fig_teleconnection_TSA_TWS_taylor_diagram.png  TELECONNECTIONS
#
#       mode                            metric  \
# 0    PRECT                   workflow_figure
# 1    PRECT                       acc_compare
# 2    PRECT                    acc_difference
# 3    PRECT                  acc_distribution
# 4      PSL                   workflow_figure
# ..     ...                               ...
# 546     TS                           summary
# 547     TS                    taylor_diagram
# 548     TS  correlation_reference_comparison
# 549     TS                           summary
# 550     TS                    taylor_diagram
#
#                                                  title  \
# 0                                    Atm ACC PRECT ACC
# 1                            Atm ACC PRECT ACC Compare
# 2                         Atm ACC PRECT ACC Difference
# 3                       Atm ACC PRECT ACC Distribution
# 4                                      Atm ACC PSL ACC
# ..                                                 ...
# 546                      Teleconnection Tsa TS Summary
# 547               Teleconnection Tsa TS Taylor Diagram
# 548  Teleconnection Tsa TWS Correlation Reference C...
# 549                     Teleconnection Tsa TWS Summary
# 550              Teleconnection Tsa TWS Taylor Diagram
#
#                                    caption
# 0    Workflow-generated diagnostic figure.
# 1    Workflow-generated diagnostic figure.
# 2    Workflow-generated diagnostic figure.
# 3    Workflow-generated diagnostic figure.
# 4    Workflow-generated diagnostic figure.
# ..                                     ...
# 546  Workflow-generated diagnostic figure.
# 547  Workflow-generated diagnostic figure.
# 548  Workflow-generated diagnostic figure.
# 549  Workflow-generated diagnostic figure.
# 550  Workflow-generated diagnostic figure.
#
# [551 rows x 6 columns]

# %% [markdown]
# ## 2. Build the webpage

# %%
output_html = generate_diagnostics_webpage(
    DIAG_DIR,
    discover_figures=True,
    figure_pattern=FIGURE_PATTERN,
    include_subdirs=INCLUDE_SUBDIRS,
)
print(f"Webpage created with {len(catalog)} figures: {output_html}")
display(HTML(f'<a href="{PORTAL_URL}" target="_blank">Open the ESP-Lab figure gallery</a>'))
# Out:
# Webpage created with 551 figures: /global/cfs/cdirs/e3sm/www/zhan391/esp-lab_diag/index.html
# <a href="https://portal.nersc.gov/cfs/e3sm/zhan391/esp-lab_diag/index.html" target="_blank">Open the ESP-Lab figure gallery</a>

# %% [markdown]
# The resulting `index.html` provides group and metric filters, text search, responsive figure cards, full-resolution viewing, and figure comparison. Generation also makes the cataloged figures publicly readable and the gallery directory publicly traversable so the portal can serve every image. Re-run the two sections whenever workflow figures are added, replaced, or removed.
